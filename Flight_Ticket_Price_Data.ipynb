# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By
import requests
import time
from selenium.common.exceptions import NoSuchElementException

# %% [markdown]
# Imported necessary libraries

# %%
driver = webdriver.Chrome(r'C:\Users\sawan\Desktop\chromedriver.exe')

# %%
url = 'https://www.easemytrip.com/'
driver.get(url)

# %% [markdown]
# Using easemytrip.com to scrap the data

# %%
url_urls=[]

# %%
clickss=driver.find_elements(By.XPATH,'//a[@class="srch_btn"]')
for i in clickss:
    url_urls.append(i.get_attribute("href"))

# %% [markdown]
# Collected URLs to scrap the data

# %%
url_urls
# Out:
# ['https://flight.easemytrip.com/FlightList/Index?org=DEL-Delhi,%20India%20,&dept=BOM-Mumbai,%20India%20,&adt=1&chd=0&inf=0&cabin=0&airline=Any&deptDT=25/9/2022&arrDT=undefined&isOneway=true&isDomestic=false',
#  'https://flight.easemytrip.com/FlightList/Index?org=BOM-Mumbai,%20India%20,&dept=DEL-Delhi,%20India%20,&adt=1&chd=0&inf=0&cabin=0&airline=Any&deptDT=25/9/2022&arrDT=undefined&isOneway=true&isDomestic=false',
#  'https://flight.easemytrip.com/FlightList/Index?org=DEL-Delhi,%20India%20,&dept=GOI-Goa,%20India%20,&adt=1&chd=0&inf=0&cabin=0&airline=Any&deptDT=25/9/2022&arrDT=undefined&isOneway=true&isDomestic=false',
#  'https://flight.easemytrip.com/FlightList/Index?org=DEL-Delhi,%20India%20,&dept=BLR-Bangalore,%20India%20,&adt=1&chd=0&inf=0&cabin=0&airline=Any&deptDT=25/9/2022&arrDT=undefined&isOneway=true&isDomestic=false',
# ...

# %%
heading1 = []
heading2 = []
heading3 = []
heading4 = []
heading5 = []
heading6 = []
heading7 = []
heading8 = []
heading9 = []
heading10 = []


for url in url_urls:
    driver.get(url)
    time.sleep(5) 
    
    Nc0click = driver.find_element(By.XPATH,'/html/body/form/div[9]/div[2]/div/div[4]/div/div/div[1]/div/div[1]/div[2]/div[1]/input[1]')
    Nc0click.click()
    
    Nc01click = driver.find_element(By.XPATH,'//li[@id="snd_5_07/10/2022"]')
    Nc01click.click()
    
    Nc5lick = driver.find_element(By.XPATH,'/html/body/form/div[9]/div[2]/div/div[4]/div/div/div[1]/div/div[1]/div[3]/button[1]')
    Nc5lick.click()
    
    time.sleep(5)

    Nclick = driver.find_element(By.XPATH,'/html/body/form/div[9]/div[5]/div/div[1]/div/div/div[13]/div[3]/div[1]/div/p')
    Nclick.click() 
    
    time.sleep(2) 
    
    try:
        column9 = driver.find_elements(By.XPATH,'//div[@class="col-md-12 col-sm-12 main-bo-lis pad-top-bot ng-scope"]')    
        for z in column9:
            heading9.append(z.text) 
    except NoSuchElementException:
        heading9.append('-') 
    
    try:
        column1 = driver.find_elements(By.XPATH,'//span[@class="txt-r4 ng-binding"]')    
        for a in column1:
            heading1.append(a.text) 
    except NoSuchElementException:
        heading1.append('-') 
        
    try:
        column2 = driver.find_elements(By.XPATH,'//span[@class="txt-r5"]')    
        for b in column2:
            heading2.append(b.text)
    except NoSuchElementException:
        heading2.append('-') 
        
    try:    
        column3 = driver.find_elements(By.XPATH,'//span[@class="txt-r5 ng-binding"]')    
        for c in column3:
            heading3.append(c.text)
    except NoSuchElementException:
        heading3.append('-')
        
    try:
        column4 = driver.find_elements(By.XPATH,'//span[@class="txt-r2-n ng-binding"]')    
        for d in column4:
            heading4.append(d.text)
    except NoSuchElementException:
        heading4.append('-') 
        
    try:
        column5 = driver.find_elements(By.XPATH,'//span[@class="txt-r3-n ng-binding"]')    
        for e in column5:
            heading5.append(e.text)
    except NoSuchElementException:
        heading5.append('-') 
        
    try:
        column6 = driver.find_elements(By.XPATH,'//span[@class="dura_md ng-binding"]')    
        for f in column6:
            heading6.append(f.text)
    except NoSuchElementException:
        heading6.append('-') 
        
    try:
        column7 = driver.find_elements(By.XPATH,'//span[@class="dura_md2 ng-scope"]')    
        for g in column7:
            heading7.append(g.text)
    except NoSuchElementException:
        heading7.append('-') 
        
    try:
        column8 = driver.find_elements(By.XPATH,'//div[@class="col-md-8 col-sm-8 col-xs-9 txt-r6-n exPrc ng-binding"]')    
        for h in column8:
            heading8.append(h.text)
    except NoSuchElementException:
        heading8.append('-') 
        
    Nclick = driver.find_element(By.XPATH,'/html/body/form/div[9]/div[5]/div/div[1]/div/div/div[13]/div[3]/div[1]/div/p')
    Nclick.click()
    
    Fclick = driver.find_element(By.XPATH,'/html/body/form/div[9]/div[5]/div/div[1]/div/div/div[13]/div[3]/div[2]/div/p')
    Fclick.click()
    
    time.sleep(2)
    
    try:
        column9 = driver.find_elements(By.XPATH,'//div[@class="col-md-12 col-sm-12 main-bo-lis pad-top-bot ng-scope"]')    
        for z in column9:
            heading9.append(z.text) 
    except NoSuchElementException:
        heading9.append('-') 
    
    try:
        column1 = driver.find_elements(By.XPATH,'//span[@class="txt-r4 ng-binding"]')    
        for a in column1:
            heading1.append(a.text) 
    except NoSuchElementException:
        heading1.append('-') 
        
    try:
        column2 = driver.find_elements(By.XPATH,'//span[@class="txt-r5"]')    
        for b in column2:
            heading2.append(b.text)
    except NoSuchElementException:
        heading2.append('-') 
        
    try:    
        column3 = driver.find_elements(By.XPATH,'//span[@class="txt-r5 ng-binding"]')    
        for c in column3:
            heading3.append(c.text)
    except NoSuchElementException:
        heading3.append('-')
        
    try:
        column4 = driver.find_elements(By.XPATH,'//span[@class="txt-r2-n ng-binding"]')    
        for d in column4:
            heading4.append(d.text)
    except NoSuchElementException:
        heading4.append('-') 
        
    try:
        column5 = driver.find_elements(By.XPATH,'//span[@class="txt-r3-n ng-binding"]')    
        for e in column5:
            heading5.append(e.text)
    except NoSuchElementException:
        heading5.append('-') 
        
    try:
        column6 = driver.find_elements(By.XPATH,'//span[@class="dura_md ng-binding"]')    
        for f in column6:
            heading6.append(f.text)
    except NoSuchElementException:
        heading6.append('-') 
        
    try:
        column7 = driver.find_elements(By.XPATH,'//span[@class="dura_md2 ng-scope"]')    
        for g in column7:
            heading7.append(g.text)
    except NoSuchElementException:
        heading7.append('-') 
        
    try:
        column8 = driver.find_elements(By.XPATH,'//div[@class="col-md-8 col-sm-8 col-xs-9 txt-r6-n exPrc ng-binding"]')    
        for h in column8:
            heading8.append(h.text)
    except NoSuchElementException:
        heading8.append('-')
        
    
    Fclick = driver.find_element(By.XPATH,'/html/body/form/div[9]/div[5]/div/div[1]/div/div/div[13]/div[3]/div[2]/div/p')
    Fclick.click()
    
    Sclick = driver.find_element(By.XPATH,'/html/body/form/div[9]/div[5]/div/div[1]/div/div/div[13]/div[3]/div[3]/div/p')
    Sclick.click()
    
    time.sleep(2)
    
    try:
        column9 = driver.find_elements(By.XPATH,'//div[@class="col-md-12 col-sm-12 main-bo-lis pad-top-bot ng-scope"]')    
        for z in column9:
            heading9.append(z.text) 
    except NoSuchElementException:
        heading9.append('-') 
    
    try:
        column1 = driver.find_elements(By.XPATH,'//span[@class="txt-r4 ng-binding"]')    
        for a in column1:
            heading1.append(a.text) 
    except NoSuchElementException:
        heading1.append('-') 
        
    try:
        column2 = driver.find_elements(By.XPATH,'//span[@class="txt-r5"]')    
        for b in column2:
            heading2.append(b.text)
    except NoSuchElementException:
        heading2.append('-') 
        
    try:    
        column3 = driver.find_elements(By.XPATH,'//span[@class="txt-r5 ng-binding"]')    
        for c in column3:
            heading3.append(c.text)
    except NoSuchElementException:
        heading3.append('-')
        
    try:
        column4 = driver.find_elements(By.XPATH,'//span[@class="txt-r2-n ng-binding"]')    
        for d in column4:
            heading4.append(d.text)
    except NoSuchElementException:
        heading4.append('-') 
        
    try:
        column5 = driver.find_elements(By.XPATH,'//span[@class="txt-r3-n ng-binding"]')    
        for e in column5:
            heading5.append(e.text)
    except NoSuchElementException:
        heading5.append('-') 
        
    try:
        column6 = driver.find_elements(By.XPATH,'//span[@class="dura_md ng-binding"]')    
        for f in column6:
            heading6.append(f.text)
    except NoSuchElementException:
        heading6.append('-') 
        
    try:
        column7 = driver.find_elements(By.XPATH,'//span[@class="dura_md2 ng-scope"]')    
        for g in column7:
            heading7.append(g.text)
    except NoSuchElementException:
        heading7.append('-') 
        
    try:
        column8 = driver.find_elements(By.XPATH,'//div[@class="col-md-8 col-sm-8 col-xs-9 txt-r6-n exPrc ng-binding"]')    
        for h in column8:
            heading8.append(h.text)
    except NoSuchElementException:
        heading8.append('-')

# %% [markdown]
# Automated the scrapping process

# %%
print(len(heading1))
print(len(heading2))
print(len(heading3))
print(len(heading4))
print(len(heading5))
print(len(heading6))
print(len(heading7))
print(len(heading8))
# Out:
# 4539
# 4539
# 4539
# 9078
# 9078
# 4539
# 4539
# 4539

# %%
heading9
# Out:
# ['GO FIRST\nG8- 328\n13:20\nDelhi\n02h 00m\nnon-stop\n15:20\nMumbai\n5,950\n+ More Fare\nBOOK NOW\nUse Promo Code: BOOKNOW to get flat Rs.450 OFF on this flight\nFlight Detail',
#  'GO FIRST\nG8- 334\n07:00\nDelhi\n02h 10m\nnon-stop\n09:10\nMumbai\n5,950\n+ More Fare\nBOOK NOW\nUse Promo Code: BOOKNOW to get flat Rs.450 OFF on this flight\nFlight Detail',
#  'GO FIRST\nG8- 336\n14:30\nDelhi\n02h 10m\nnon-stop\n16:40\nMumbai\n5,950\n+ More Fare\nBOOK NOW\nUse Promo Code: BOOKNOW to get flat Rs.450 OFF on this flight\nFlight Detail',
#  'SpiceJet\nSG-8701\n07:20\nDelhi\n02h 15m\nnon-stop\n09:35\nMumbai\n5,950\n+ More Fare\nBOOK NOW\nUse Promo Code: BOOKNOW to get flat Rs.450 OFF on this flight\nFlight Detail',
#  'GO FIRST\nG8- 323\n18:20\nDelhi\n02h 15m\nnon-stop\n20:35\nMumbai\n5,950\n+ More Fare\nBOOK NOW\nUse Promo Code: BOOKNOW to get flat Rs.450 OFF on this flight\nFlight Detail',
# ...

# %%
df1 = pd.DataFrame({'test':heading9})

# %%
df1 = df1['test'].str.split('\n',expand=True)

# %%
df1 = df1[[0,1,2,3,4,5,6,7,8]]

# %%
df1
# Out:
#              0        1      2       3        4         5      6          7  \
# 0     GO FIRST  G8- 328  13:20   Delhi  02h 00m  non-stop  15:20     Mumbai
# 1     GO FIRST  G8- 334  07:00   Delhi  02h 10m  non-stop  09:10     Mumbai
# 2     GO FIRST  G8- 336  14:30   Delhi  02h 10m  non-stop  16:40     Mumbai
# 3     SpiceJet  SG-8701  07:20   Delhi  02h 15m  non-stop  09:35     Mumbai
# 4     GO FIRST  G8- 323  18:20   Delhi  02h 15m  non-stop  20:35     Mumbai
# ...        ...      ...    ...     ...      ...       ...    ...        ...
# 4534               None   None    None     None      None   None       None
# 4535               None   None    None     None      None   None       None
# 4536   Vistara   UK-852  12:10  Mumbai  08h 15m   2+-stop  20:25  Bangalore
# 4537               None   None    None     None      None   None       None
# 4538               None   None    None     None      None   None       None
#
#            8
# 0      5,950
# 1      5,950
# ...

# %%
import numpy as np

# %%
df1 = df1.replace({'NaN':'-', "":'-', " ":'-', 'None':'-',None:"-",np.nan:'-'})

# %%
df1 = df1.replace({"-":np.nan})

# %%
df1
# Out:
#              0        1      2       3        4         5      6          7  \
# 0     GO FIRST  G8- 328  13:20   Delhi  02h 00m  non-stop  15:20     Mumbai
# 1     GO FIRST  G8- 334  07:00   Delhi  02h 10m  non-stop  09:10     Mumbai
# 2     GO FIRST  G8- 336  14:30   Delhi  02h 10m  non-stop  16:40     Mumbai
# 3     SpiceJet  SG-8701  07:20   Delhi  02h 15m  non-stop  09:35     Mumbai
# 4     GO FIRST  G8- 323  18:20   Delhi  02h 15m  non-stop  20:35     Mumbai
# ...        ...      ...    ...     ...      ...       ...    ...        ...
# 4534       NaN      NaN    NaN     NaN      NaN       NaN    NaN        NaN
# 4535       NaN      NaN    NaN     NaN      NaN       NaN    NaN        NaN
# 4536   Vistara   UK-852  12:10  Mumbai  08h 15m   2+-stop  20:25  Bangalore
# 4537       NaN      NaN    NaN     NaN      NaN       NaN    NaN        NaN
# 4538       NaN      NaN    NaN     NaN      NaN       NaN    NaN        NaN
#
#            8
# 0      5,950
# 1      5,950
# ...

# %%
df1 = df1.dropna(axis=0, how='all')

# %% [markdown]
# Removed all NaN values

# %%
for i in df1.columns:
    a = df1[i].isna().sum()
    if a > 0:
        print(i,'column has',a,'NaN values')

# %%
df1[8].value_counts()
# Out:
# 9,419     30
# 5,943     26
# 5,954     21
# 8,579     20
# 7,098     19
#           ..
# 18,660     1
# 17,603     1
# 16,203     1
# 16,630     1
# 26,123     1
# Name: 8, Length: 742, dtype: int64

# %%
df1 = df1.replace({'1-stop':1,
                   'non-stop':0,
                   '2+-stop':2,
                   '1-stop Via IDR':1,
                   '1-stop Via Indore':1,
                   '1-stop Via RPR':1,
                   '1-stop Via Guwahati':1,
                   '1-stop Via Ahmedabad':1
                  })

# %%
df = pd.DataFrame({'test':df1[8]})

# %%
df = df['test'].str.split(',', expand=True)

# %%
df['test'] = df[0] + '' + df[1]

# %%
df1[8] = df['test']

# %%
df1
# Out:
#               0        1      2       3        4  5      6          7      8
# 0      GO FIRST  G8- 328  13:20   Delhi  02h 00m  0  15:20     Mumbai   5950
# 1      GO FIRST  G8- 334  07:00   Delhi  02h 10m  0  09:10     Mumbai   5950
# 2      GO FIRST  G8- 336  14:30   Delhi  02h 10m  0  16:40     Mumbai   5950
# 3      SpiceJet  SG-8701  07:20   Delhi  02h 15m  0  09:35     Mumbai   5950
# 4      GO FIRST  G8- 323  18:20   Delhi  02h 15m  0  20:35     Mumbai   5950
# ...         ...      ...    ...     ...      ... ..    ...        ...    ...
# 4526  Air India   AI-615  06:00  Mumbai  10h 15m  2  16:15  Bangalore  18543
# 4527  Air India   AI-615  06:00  Mumbai  14h 15m  2  20:15  Bangalore  19593
# 4528  Air India   AI-615  06:00  Mumbai  12h 20m  2  18:20  Bangalore  20118
# 4529  Air India   AI-617  11:05  Mumbai  13h 00m  2  00:05  Bangalore  20223
# 4536    Vistara   UK-852  12:10  Mumbai  08h 15m  2  20:25  Bangalore  26123
#
# [1513 rows x 9 columns]

# %% [markdown]
# Cleaned the data and organized data to save

# %%
df1.to_csv('FlightPrice.csv')

# %% [markdown]
# Saved the data

# %%
driver.close()
